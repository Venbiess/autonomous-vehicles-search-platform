# %%
import pandas as pd
from PIL import Image
import io
import matplotlib.pyplot as plt

# %%
df = pd.read_parquet("../backend/data/10017090168044687777_6380_000_6400_000.parquet")

image_bytes = df[df['key.camera_name'] == 1]['[CameraImageComponent].image'].iloc[0]
image = Image.open(io.BytesIO(image_bytes))

plt.imshow(image)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'key.camera_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 3
# ...

# %%
df.columns
df["key.frame_timestamp_micros"] / (10 ** 6)

pd.to_datetime(df["key.frame_timestamp_micros"], unit="us", utc=True)
# Out:
# index
# 10017090168044687777_6380_000_6400_000;1550083467346370   2019-02-13 18:44:27.346370+00:00
# 10017090168044687777_6380_000_6400_000;1550083467446163   2019-02-13 18:44:27.446163+00:00
# 10017090168044687777_6380_000_6400_000;1550083467545990   2019-02-13 18:44:27.545990+00:00
# 10017090168044687777_6380_000_6400_000;1550083467645823   2019-02-13 18:44:27.645823+00:00
# 10017090168044687777_6380_000_6400_000;1550083467745665   2019-02-13 18:44:27.745665+00:00
#                                                                         ...
# 10017090168044687777_6380_000_6400_000;1550083486648566   2019-02-13 18:44:46.648566+00:00
# 10017090168044687777_6380_000_6400_000;1550083486748588   2019-02-13 18:44:46.748588+00:00
# 10017090168044687777_6380_000_6400_000;1550083486848524   2019-02-13 18:44:46.848524+00:00
# 10017090168044687777_6380_000_6400_000;1550083486948500   2019-02-13 18:44:46.948500+00:00
# ...

# %%
df["ts"] = pd.to_datetime(df["key.frame_timestamp_micros"], unit="us", utc=True)
df = df.sort_values("ts")

# df_step = (
#     df
#     .set_index("ts")
#     .resample(f"{0.1}s")
#     .first()      # или .last(), .mean(), .nearest()
#     .dropna()
#     .reset_index()
# )
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df["ts"] = pd.to_datetime(df["key.frame_timestamp_micros"], unit="us", utc=True)
#       2 df = df.sort_values("ts")
#       4 # df_step = (
#       5 #     df
#       6 #     .set_index("ts")
#    (...)
#      10 #     .reset_index()
#      11 # )
#
# NameError: name 'pd' is not defined

# %%
import sys
sys.path.append('..')
from backend.processors.waymo_preprocessor import WaymoPreprocessor

processor = WaymoPreprocessor(resample_seconds=0.5)
for i, episode in enumerate(processor):
    break

df = pd.read_parquet("../backend/data/10017090168044687777_6380_000_6400_000.parquet")
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 3
#       1 import sys
#       2 sys.path.append('..')
# ----> 3 from backend.processors.waymo_preprocessor import WaymoPreprocessor
#       5 processor = WaymoPreprocessor(resample_seconds=0.5)
#       6 for i, episode in enumerate(processor):
#
# File /app/autonomous-vehicles-search-platform/notebooks/../backend/processors/waymo_preprocessor.py:1
# ----> 1 from preprocessor import Preprocessor
#       2 from google.cloud import storage
#       3 from typing import List, Optional
#
# ModuleNotFoundError: No module named 'preprocessor'
